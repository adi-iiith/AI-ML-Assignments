# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import operator
import seaborn as sns
import pprint
from collections import OrderedDict

# %%
# loading the data in a dataframe
cname=['satisfaction_level','last_evaluation','number_project','avg_monthly_hours','time_spend','work_accident','target','promotion','sales','salary']
file = 'train.csv'
df = pd.read_csv(file)
x = np.unique(df['left'], return_counts = True)

c_list = ['satisfaction_level','last_evaluation','number_project','average_montly_hours','time_spend_company','Work_accident','promotion_last_5years','sales','salary','left']
df1 = df[c_list]

# print(df1)
train_set = df1.sample(frac=0.8,random_state=200)
validate_set = df1.drop(train_set.index)
x = np.unique(train_set['left'], return_counts = True)
print(x)
c_list.remove('left')
# train_set
# Out:
# (array([0, 1]), array([6813, 2177]))

# %%
#implement Entropy --- takes input ( dataframe , column_name )

def entropy_(df):
    total = df['left'].count()
    positive = df[df['left'] == 1]
    pos_c = positive['left'].count()
    neg_c = total - pos_c
    if pos_c == 0 or neg_c == 0 :
        return 0
    ent = - (pos_c/total * math.log(pos_c/total,2) 
                 + neg_c/total * math.log(neg_c/total,2))
    return ent
    
# entropy_(df1)

# %%
def temp_f(data,a):
    return ([data[a].unique()])
def IG(data,attribute,entropy):
    isum = 0
    t = len(data.index)
    label = (data[attribute].unique()).tolist()
    for i in label:
        sdf = data[data[attribute] == i]
        isum = isum + ((len(sdf.index)/t) * entropy_(sdf))
    return entropy - isum
# e = entropy_(df1)
# print(IG(df1,'salary',e))

# %%
# best attribute

def best_attribute(df,attribute):
    e = entropy_(df)
    attribute_list = {}
    for best in attribute :
        attribute_list[best] = IG(df , best , e)
#     m = -1
#     for i in attribute_list:
#         if attribute_list[i] > m:
#             m=attribute_list[i]
#             b = i
    b = max(attribute_list, key=attribute_list.get)
    return b

# %%
numeric_data = ['satisfaction_level','last_evaluation','number_project',
                'average_montly_hours','time_spend_company']
attribute_dict = {}

# %%
def convert(df,attr):
    mapp = {}
    check = []
    avg = []
    label = 0
    llist = []
    sortd = df.sort_values(attr)
    uv = sortd[attr].unique().tolist()
    for i in uv:
        temp = sortd[sortd[attr] == i]
        mapp[i] = np.unique(temp['left'])[np.argmax(np.unique(temp['left'],return_counts=True)[1])]
        
    prev = uv[0]
    h = mapp[uv[0]]
    for i in uv[1:len(uv)]:
        if mapp[i] == h:
            prev =i
            continue
        else :
            h = 1-h
            check.append(prev)
            prev = i
            check.append(i)
    for i in range(0,len(check),2):
        avg.append((check[i]+check[i+1])/2)
    attribute_dict[attr] = avg
    for i in df.index:
        attv = df.loc[i,attr]
        label = 0
        f = 0
        for a in avg:
            if attv < a:
                f = 1
                llist.append(label)
                break
            else :
                label += 1
        if f == 0:
            llist.append(label)
    
    df = df.drop(attr,axis=1)           ##
    new1 = pd.Series(llist)              ##
    df[attr] = new1.values
    return df
# convert(train_set,'satisfaction_level')

# %%
## call on all attr

for i in numeric_data:
    train_set = convert(train_set,i)

# %%
print(train_set)
# Out:
#        Work_accident  promotion_last_5years        sales  salary  left  \
# 10111              0                      0      support     low     0
# 652                0                      0           IT     low     0
# 600                0                      0      support     low     0
# 3588               0                      0    technical    high     1
# 242                1                      0           IT     low     0
# 4071               0                      0   accounting  medium     1
# 980                0                      1      support     low     0
# 10761              0                      0      support  medium     0
# 8313               0                      0        sales     low     1
# 4583               0                      0           hr     low     1
# 1025               0                      0        sales     low     0
# 9019               0                      0    technical  medium     0
# 9462               0                      0        sales  medium     0
# 1624               0                      0   management     low     0
# 419                1                      0      support     low     0
# 3661               0                      0        sales     low     1
# 1030               0                      0           IT  medium     0
# 2520               0                      0        sales  medium     0
# 10696              0                      0        sales     low     0
# 5264               0                      0    technical     low     1
# 8108               0                      0    technical     low     1
# 9568               0                      0  product_mng  medium     0
# 10323              0                      0    technical  medium     0
# 3228               0                      0      support     low     0
# 356                1                      0   management  medium     0
# 3776               0                      0  product_mng     low     1
# 337                0                      0    technical  medium     1
# 7931               0                      0    marketing     low     0
# 8411               1                      0      support     low     0
# 7255               0                      0        sales  medium     0
# ...              ...                    ...          ...     ...   ...
# 7960               1                      0   management    high     0
# 7471               0                      0        sales    high     0
# 9954               0                      0        sales  medium     0
# 10066              0                      0   accounting     low     1
# 6961               0                      0        sales     low     0
# 4421               1                      0           IT  medium     0
# 4535               0                      0           hr  medium     1
# 326                1                      0        sales     low     1
# 9584               0                      0        sales  medium     0
# 9862               0                      0      support    high     0
# 6439               0                      0   accounting    high     0
# 956                0                      0           hr     low     0
# 10678              0                      0        sales  medium     0
# 1777               1                      0        sales  medium     0
# 4822               0                      0        sales  medium     0
# 1860               0                      0   management     low     0
# 631                0                      0  product_mng  medium     0
# 5874               1                      0    technical     low     0
# 5061               0                      0    technical  medium     0
# 10280              0                      0      support  medium     1
# 11093              1                      0    technical     low     0
# 4947               0                      0           IT     low     0
# 1580               0                      0    technical  medium     1
# 7263               1                      0        sales     low     0
# 1889               0                      0    technical     low     1
# 7990               0                      0    marketing  medium     0
# 693                0                      0        RandD     low     0
# 8686               1                      0        sales  medium     1
# 9998               0                      0      support     low     0
# 10109              0                      0        sales  medium     1
#
#        satisfaction_level  last_evaluation  number_project  \
# 10111                   3                2               1
# 652                     3                2               1
# 600                     3                2               1
# 3588                    2                2               0
# 242                     3                2               1
# 4071                    0                2               2
# 980                     3                0               0
# 10761                   3                2               1
# 8313                    3                2               1
# 4583                    3                2               1
# 1025                    3                2               1
# 9019                    1                2               2
# 9462                    3                2               1
# 1624                    3                2               1
# 419                     3                2               1
# 3661                    3                2               1
# 1030                    3                2               1
# 2520                    1                2               1
# 10696                   3                2               1
# 5264                    2                1               0
# 8108                    2                2               0
# 9568                    3                2               2
# 10323                   3                2               1
# 3228                    3                2               1
# 356                     3                2               1
# 3776                    0                2               2
# 337                     2                2               0
# 7931                    3                2               1
# 8411                    1                2               2
# 7255                    3                2               1
# ...                   ...              ...             ...
# 7960                    3                2               1
# 7471                    3                2               0
# 9954                    3                2               1
# 10066                   2                2               0
# 6961                    3                2               1
# 4421                    3                2               1
# 4535                    0                2               2
# 326                     2                2               0
# 9584                    1                2               1
# 9862                    1                2               1
# 6439                    3                2               1
# 956                     3                2               1
# 10678                   3                2               1
# 1777                    1                2               1
# 4822                    3                2               1
# 1860                    3                2               1
# 631                     3                2               1
# 5874                    3                2               1
# 5061                    1                2               1
# 10280                   3                3               1
# 11093                   3                2               1
# 4947                    3                2               1
# 1580                    0                2               2
# 7263                    3                2               0
# 1889                    2                1               0
# 7990                    3                2               1
# 693                     3                2               1
# 8686                    1                2               1
# 9998                    1                2               1
# 10109                   0                2               2
#
#        average_montly_hours  time_spend_company
# 10111                     2                   0
# 652                       2                   0
# 600                       2                   0
# 3588                      2                   0
# 242                       2                   0
# 4071                      7                   0
# 980                       2                   1
# 10761                     2                   0
# 8313                      2                   1
# 4583                      2                   1
# 1025                      2                   0
# 9019                      2                   0
# 9462                      2                   0
# 1624                      2                   0
# 419                       2                   0
# 3661                      2                   1
# 1030                      2                   0
# 2520                      2                   2
# 10696                     2                   0
# 5264                      1                   0
# 8108                      2                   0
# 9568                      0                   0
# 10323                     2                   0
# 3228                      2                   0
# 356                       2                   0
# 3776                      2                   0
# 337                       2                   0
# 7931                      2                   0
# 8411                      2                   1
# 7255                      2                   0
# ...                     ...                 ...
# 7960                      1                   0
# 7471                      2                   0
# 9954                      2                   0
# 10066                     2                   0
# 6961                      2                   0
# 4421                      2                   0
# 4535                      2                   0
# 326                       2                   0
# 9584                      0                   1
# 9862                      2                   0
# 6439                      2                   0
# 956                       2                   0
# 10678                     2                   2
# 1777                      2                   0
# 4822                      2                   0
# 1860                      2                   0
# 631                       2                   0
# 5874                      2                   0
# 5061                      5                   0
# 10280                     2                   2
# 11093                     2                   0
# 4947                      2                   2
# 1580                      7                   0
# 7263                      2                   1
# 1889                      2                   0
# 7990                      2                   0
# 693                       2                   0
# 8686                      3                   1
# 9998                      2                   0
# 10109                     2                   0
#
# [8990 rows x 10 columns]

# %%
def tree(df , attribute_list , pd , root=None):
    if len(np.unique(df['left'])) <=1 :
        return {'predict': np.unique(df['left'])[0]}
    elif len(attribute_list) == 0:
        t = np.argmax(np.unique(df['left'], return_counts = True)[1])
        return {'predict': np.unique(df['left'])[t]}
    elif len(df) == 0:
        t = np.argmax(np.unique(pd['left'], return_counts = True)[1])
        return {'predict': np.unique(pd['left'])[t]}
    b = best_attribute(df,attribute_list[:])
    attribute_list.remove(b)
    # tree empty
    if root is None:
        root = {}
        root[b] = {}
    for i in df[b].unique():
        new_df = df[df[b]==i]
        root[b][i] = tree( new_df , attribute_list[:] , df)
    return root
# print (c_list)
root = tree(train_set,c_list[:],train_set)
print(root)
# Out:
# {'satisfaction_level': {3: {'time_spend_company': {0: {'average_montly_hours': {2: {'number_project': {1: {'sales': {'support': {'salary': {'low': {'last_evaluation': {2: {'promotion_last_5years': {0: {'Work_accident': {0: {'predict': 0}, 1: {'predict': 0}}}, 1: {'predict': 0}}}, 3: {'predict': 0}, 0: {'predict': 0}}}, 'medium': {'Work_accident': {0: {'last_evaluation': {2: {'promotion_last_5years': {0: {'predict': 0}, 1: {'predict': 0}}}, 3: {'predict': 0}, 0: {'predict': 0}}}, 1: {'predict': 0}}}, 'high': {'predict': 0}}}, 'IT': {'predict': 0}, 'sales': {'last_evaluation': {2: {'salary': {'low': {'Work_accident': {0: {'promotion_last_5years': {0: {'predict': 0}, 1: {'predict': 0}}}, 1: {'predict': 0}}}, 'medium': {'promotion_last_5years': {0: {'Work_accident': {0: {'predict': 0}, 1: {'predict': 0}}}, 1: {'predict': 0}}}, 'high': {'predict': 0}}}, 3: {'salary': {'medium': {'Work_accident': {0: {'promotion_last_5years': {0: {'predict': 0}}}, 1: {'predict': 0}}}, 'low': {'predict': 0}}}, 1: {'Work_accident': {0: {'promotion_last_5years': {0: {'salary': {'low': {'predict': 0}}}}}, 1: {'predict': 0}}}, 0: {'predict': 0}}}, 'management': {'promotion_last_5years': {0: {'predict': 0}, 1: {'salary': {'high': {'predict': 0}, 'medium': {'predict': 0}, 'low': {'predict': 1}}}}}, 'technical': {'Work_accident': {0: {'salary': {'medium': {'last_evaluation': {2: {'promotion_last_5years': {0: {'predict': 0}, 1: {'predict': 0}}}, 1: {'predict': 0}, 0: {'predict': 0}, 3: {'predict': 0}}}, 'low': {'last_evaluation': {2: {'promotion_last_5years': {0: {'predict': 0}, 1: {'predict': 0}}}, 3: {'predict': 0}, 0: {'predict': 0}}}, 'high': {'predict': 0}}}, 1: {'predict': 0}}}, 'marketing': {'salary': {'low': {'Work_accident': {0: {'last_evaluation': {2: {'promotion_last_5years': {0: {'predict': 0}, 1: {'predict': 0}}}, 3: {'predict': 0}, 0: {'predict': 0}}}, 1: {'predict': 0}}}, 'high': {'predict': 0}, 'medium': {'predict': 0}}}, 'RandD': {'salary': {'high': {'predict': 0}, 'medium': {'predict': 0}, 'low': {'Work_accident': {0: {'last_evaluation': {2: {'promotion_last_5years': {0: {'predict': 0}}}, 0: {'predict': 0}, 1: {'predict': 0}, 3: {'predict': 0}}}, 1: {'predict': 0}}}}}, 'accounting': {'last_evaluation': {2: {'predict': 0}, 3: {'salary': {'low': {'Work_accident': {0: {'promotion_last_5years': {0: {'predict': 0}}}}}, 'medium': {'predict': 0}}}, 1: {'predict': 0}}}, 'hr': {'salary': {'low': {'Work_accident': {0: {'last_evaluation': {2: {'promotion_last_5years': {0: {'predict': 0}, 1: {'predict': 0}}}, 0: {'predict': 0}}}, 1: {'predict': 0}}}, 'medium': {'Work_accident': {0: {'last_evaluation': {2: {'promotion_last_5years': {0: {'predict': 0}, 1: {'predict': 0}}}, 0: {'predict': 0}}}, 1: {'predict': 0}}}, 'high': {'predict': 0}}}, 'product_mng': {'predict': 0}}}, 0: {'sales': {'technical': {'Work_accident': {0: {'salary': {'low': {'last_evaluation': {2: {'promotion_last_5years': {0: {'predict': 0}}}, 1: {'predict': 0}}}, 'medium': {'last_evaluation': {2: {'promotion_last_5years': {0: {'predict': 0}}}}}, 'high': {'predict': 0}}}, 1: {'predict': 0}}}, 'support': {'salary': {'low': {'Work_accident': {1: {'predict': 0}, 0: {'last_evaluation': {2: {'promotion_last_5years': {0: {'predict': 0}}}, 0: {'predict': 0}}}}}, 'medium': {'predict': 0}, 'high': {'predict': 0}}}, 'sales': {'last_evaluation': {2: {'Work_accident': {0: {'salary': {'high': {'predict': 0}, 'medium': {'promotion_last_5years': {0: {'predict': 0}}}, 'low': {'promotion_last_5years': {0: {'predict': 0}}}}}, 1: {'predict': 0}}}, 1: {'salary': {'medium': {'predict': 0}, 'low': {'predict': 1}}}, 0: {'predict': 0}}}, 'IT': {'predict': 0}, 'product_mng': {'predict': 0}, 'RandD': {'last_evaluation': {2: {'predict': 0}, 1: {'predict': 0}, 3: {'predict': 1}}}, 'management': {'predict': 0}, 'accounting': {'predict': 0}, 'marketing': {'predict': 0}, 'hr': {'predict': 0}}}, 2: {'last_evaluation': {2: {'sales': {'sales': {'salary': {'medium': {'predict': 0}, 'low': {'Work_accident': {0: {'promotion_ ...

# %%
def prediction_convert(df,attr):
    avg = attribute_dict[attr]
    label = 0
    llist =[]
    for i in df.index:
        attv = df.loc[i,attr]
        label = 0
        f = 0
        for a in avg:
            if attv < a:
                f = 1
                llist.append(label)
                break
            else :
                label += 1
        if f == 0:
            llist.append(label)
    
    df = df.drop(attr,axis=1)           ##
    new1 = pd.Series(llist)              ##
    df[attr] = new1.values
    return df

# %%
for i in numeric_data:
    validate_set = prediction_convert(validate_set,i)

# %%
def compare(row,root):
    try:
        if list(root.keys())[0] == 'predict':
            return root['predict']
        else:
            value = row[list(root.keys())[0]]
            return compare(row,root[list(root.keys())[0]][value])
    except:
        return 0

# %%
prediction = []  
def test(root,df):
    for index,row in df.iterrows():
        prediction.append(compare(row,root))
test(root,validate_set)

# %%
actual = validate_set['left'].tolist()

def final_prediction_list():
    prediction_list= OrderedDict()
    tp,fp,tn,fn = 0,0,0,0
    for i in range(len(actual)):
        if prediction[i] == actual[i]:
            if prediction[i] == 1:
                tp += 1
            elif prediction[i] == 0:
                tn += 1
        else:
            if actual[i] == 1:
                fn += 1
            elif actual[i] == 0:
                fp += 1
    prediction_list['True Positive'] = tp
    prediction_list['False Positive'] = fp
    prediction_list['True Negative'] = tn
    prediction_list['False Negative'] = fn
    accuracy = (tp+tn)/len(actual)
    precision = (tp)/(tp+fp)
    recall = (tp)/(tp+fn)
    f1_score = 2/(1/recall + 1/precision)
    prediction_list['Accuracy'] = accuracy
    prediction_list['Precision'] = precision
    prediction_list['Recall'] = recall
    prediction_list['F1_Score'] = f1_score
    pp = pprint.PrettyPrinter(indent=6)
    for i, (key, value) in enumerate(prediction_list.items()):
        print(key + ":: ", value)
        print("")
final_prediction_list()
# Out:
# True Positive::  455
#
# False Positive::  51
#
# True Negative::  1699
#
# False Negative::  43
#
# Accuracy::  0.958185053380783
#
# Precision::  0.8992094861660079
#
# Recall::  0.9136546184738956
#
# F1_Score::  0.9063745019920318
